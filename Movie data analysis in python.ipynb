# %%
# Import the required libraries for the analysis
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('movies.csv')
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# Check for duplicates
print(df.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7663    False
# 7664    False
# 7665    False
# 7666    False
# 7667    False
# Length: 7668, dtype: bool

# %%
# Check for 'NAN' OR NOT A NUMBER as a missing data
print(df.isnull(). values.sum() != 0)
# Out:
# True

# %%
# Check for missing values in the data
df.isnull()
# Out:
#        name  rating  genre   year  released  score  votes  director  writer  \
# 0     False   False  False  False     False  False  False     False   False
# 1     False   False  False  False     False  False  False     False   False
# 2     False   False  False  False     False  False  False     False   False
# 3     False   False  False  False     False  False  False     False   False
# 4     False   False  False  False     False  False  False     False   False
# ...     ...     ...    ...    ...       ...    ...    ...       ...     ...
# 7663  False    True  False  False     False  False  False     False   False
# 7664  False    True  False  False     False  False  False     False   False
# 7665  False    True  False  False     False  False  False     False   False
# 7666  False    True  False  False     False   True   True     False   False
# 7667  False    True  False  False     False  False  False     False   False
#
#        star  country  budget  gross  company  runtime
# ...

# %%
# Count no of missing values
print(df.isnull(). sum())
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
# Check for 'NAN' OR NOT A NUMBER as a missing data
print(df!= float('NAN'))
# Out:
#       name  rating  genre  year  released  score  votes  director  writer  \
# 0     True    True   True  True      True   True   True      True    True
# 1     True    True   True  True      True   True   True      True    True
# 2     True    True   True  True      True   True   True      True    True
# 3     True    True   True  True      True   True   True      True    True
# 4     True    True   True  True      True   True   True      True    True
# ...    ...     ...    ...   ...       ...    ...    ...       ...     ...
# 7663  True    True   True  True      True   True   True      True    True
# 7664  True    True   True  True      True   True   True      True    True
# 7665  True    True   True  True      True   True   True      True    True
# 7666  True    True   True  True      True   True   True      True    True
# 7667  True    True   True  True      True   True   True      True    True
#
#       star  country  budget  gross  company  runtime
# ...

# %%
# Drop NaN and replace with 0
df1 = df.replace('NaN', np.nan)

# %%
# Replace 'NaN' with 0
df2 = df1.fillna(0)

# %%
# Confirm missing values sorted
print(df2.isnull(). sum())
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
# Drop unwanted columns
df3 = df2.drop(columns = ['writer', 'star', 'country'])
df3
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
# Check missing spellings in the name column
df3['name'].unique()
# Out:
# array(['The Shining', 'The Blue Lagoon',
#        'Star Wars: Episode V - The Empire Strikes Back', ...,
#        'Saving Mbango', "It's Just Us", 'Tee em el'], dtype=object)

# %%
# Creat a new column 'net income' from budget and gross fields
df3 = df2.assign(net_income = lambda x: x.gross - x.budget)
df3.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Order by net income in desecending order
df3.sort_values(by = ['budget'], inplace = False, ascending = False)
# Out:
#                                           name rating   genre  year  \
# 7445                         Avengers: Endgame  PG-13  Action  2019
# 7244                    Avengers: Infinity War  PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi  PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End  PG-13  Action  2007
# 7066                            Justice League  PG-13  Action  2017
# ...                                        ...    ...     ...   ...
# 2139                            One False Move      R   Crime  1992
# 2136                            Unlawful Entry      R   Crime  1992
# 2130                                 Sidekicks     PG  Action  1992
# 5916                  Martha Marcy May Marlene      R   Drama  2011
# 7667                                 Tee em el      0  Horror  2020
#
#                                released  score     votes         director  \
# 7445     April 26, 2019 (United States)    8.4  903000.0    Anthony Russo
# ...

# %%
# Explore the cleaned data
print(df3.shape)
df3.describe()
# Out:
# (7668, 16)
#               year        score         votes        budget         gross  \
# count  7668.000000  7668.000000  7.668000e+03  7.668000e+03  7.668000e+03
# mean   2000.405451     6.387911  8.807403e+04  2.551350e+07  7.656567e+07
# std      11.153508     0.976862  1.633011e+05  3.858954e+07  1.641217e+08
# min    1980.000000     0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1991.000000     5.800000  9.100000e+03  0.000000e+00  3.860582e+06
# 50%    2000.000000     6.500000  3.300000e+04  1.200000e+07  1.895543e+07
# 75%    2010.000000     7.100000  9.300000e+04  3.200000e+07  7.262022e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime    net_income
# count  7668.000000  7.668000e+03
# mean    107.205660  5.105216e+07
# std      18.737179  1.375610e+08
# min       0.000000 -1.580311e+08
# 25%      95.000000  0.000000e+00
# 50%     104.000000  7.211375e+06
# 75%     116.000000  4.372979e+07
# ...

# %%
# Slicing genre column
df3['genre']
# Out:
# 0           Drama
# 1       Adventure
# 2          Action
# 3          Comedy
# 4          Comedy
#           ...
# 7663        Drama
# 7664       Comedy
# 7665        Drama
# 7666        Drama
# 7667       Horror
# Name: genre, Length: 7668, dtype: object

# %%
# A barchart with sns showing count of movie genre in descending order
sns.countplot(y = 'genre',data = df3, order = df3['genre'].value_counts().index)
plt.figure(figsize=(14,10))
matplotlib.rcParams['figure.figsize'] = (14, 8)
plt.show()

# %%
# Creat a correlation marix and heatmap using the new dataframe

cor = df3.corr(method = 'pearson')

# The heatmap shows gross and votes are strongly correlated with budget

sns.heatmap(cor, annot = True)
# Out:
# <AxesSubplot:>

# %%
# Display high correlated variables > 0.6
cor = df3.corr(method = 'pearson')
Pair = cor
corr_pair = Pair.unstack()
corr_sort = corr_pair.sort_values()
High_corr = corr_sort[(corr_sort) > 0.6]
High_corr
# Out:
# net_income  budget        0.614473
# budget      net_income    0.614473
# votes       net_income    0.618469
# net_income  votes         0.618469
# votes       gross         0.632870
# gross       votes         0.632870
# budget      gross         0.750157
# gross       budget        0.750157
# net_income  gross         0.982644
# gross       net_income    0.982644
# year        year          1.000000
# budget      budget        1.000000
# gross       gross         1.000000
# votes       votes         1.000000
# score       score         1.000000
# runtime     runtime       1.000000
# net_income  net_income    1.000000
# dtype: float64

# %%
# Scatter plot of the correlated variables (net_income vs budget)

# Add top 3 movies with highest net income

plt.scatter('budget', 'net_income', data = df3, alpha = 0.9, s = 5)
plt.title('Budget vs Net Income')
plt.xlabel('Budget')
plt.ylabel('Net Earnings')
plt.text(237000000.0, 2.610246e+09, 'Avatar')
plt.text(356000000.0, 2.441501e+09, 'Avengers: Endgame')
plt.text(200000000.0, 2.001647e+09, 'Titanic')
plt.xscale('log')
plt.show()

# %%
# Scatter plot of the correlated variables (votes vs gross)

plt.scatter('votes', 'net_income', data = df3, alpha = 0.9, s = 5 )
plt.title('Votes received vs Net income')
plt.xlabel('Votes received')
plt.ylabel('Net Earnings')
plt.text(1100000.0, 2.610246e+09, 'Avatar')
plt.text(903000.0, 2.441501e+09, 'Avengers: Endgame')
plt.text(1100000.0, 2.001647e+09, 'Titanic')
plt.xscale('log')
plt.show()

# %%
# Result shows that (1) net earnings is positively associated with cost of production and public perception of the movie
# (2) Avatar followed by Avengers:Endagame and Titanic have the highest earnings.
